# %%
# !pip install google-genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-genai in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (1.47.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-genai) (2.50.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-genai) (2.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-genai) (4.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (50.0.1)
# Requirement already satisfied: certifi in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.14.1->google-genai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.4)

# %%
import os
from dotenv import load_dotenv, find_dotenv
from google import genai

load_dotenv(find_dotenv())
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
client = genai.Client(api_key=GEMINI_API_KEY)
# Out:
# /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages/google/auth/__init__.py:54: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/victoruccetina/Library/Python/3.9/lib/python/site-packages/google/oauth2/__init__.py:40: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)

# %%
response = client.models.generate_content(
    model="gemini-3.6-flash",
    contents="Explica qué es un LLM.",
)

print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# Un **LLM** (siglas en inglés de *Large Language Model*, o **Gran Modelo de Lenguaje** en español) es un tipo de algoritmo de Inteligencia Artificial diseñado para **entender, procesar, resumir y generar texto** de una manera que imita la forma en que escribimos y hablamos los humanos.
#
# Para entenderlo mejor, podemos desglosar su nombre y su funcionamiento:
#
# ---
#
# ### 1. ¿Por qué se llama "Gran Modelo de Lenguaje"?
# * **Modelo de Lenguaje:** Es un sistema matemático entrenado para calcular la probabilidad de que una palabra siga a otra.
# * **Gran (*Large*):** Se refiere a dos cosas gigantescas:
#   1. **La cantidad de datos:** Se entrenan leyendo volúmenes masivos de texto de internet (libros, artículos, páginas web, código de programación).
#   2. **Los parámetros:** Son las "conexiones internas" del modelo (a menudo cientos de miles de millones) que le permiten captar matices, tono, gramática y contexto.
#
# ---
#
# ### 2. ¿Cómo funciona por dentro? (De forma sencilla)
# En su nivel más básico, un LLM es un **predicteur avanzado de palabras**.
#
# Cuando le haces una pregunta, el modelo no "piensa" ni "recuerda" como un ser humano, ni tampoco busca en Google en tiempo real (a menos que esté conectado a un buscador). Lo que hace es analizar tu texto y calcular, palabra por palabra (o fragmento por fragmento), **cuál es la palabra más lógica y probable que debería venir a continuación**.
#
# Esto lo logra gracias a una tecnología llamada **Transformers** (creada por Google en 2017), que le permite al modelo analizar oraciones complejas y entender la relación entre palabras que están muy alejadas entre sí dentro de un mismo texto.
#
# ---
#
# ### 3. Ejemplos populares de LLM
# * **GPT-4o** (OpenAI, usado en ChatGPT)
# * **Gemini** (Google)
# * **Claude** (Anthropic)
# * **Llama** (Meta, un modelo de código abierto)
#
# ---
#
# ### 4. ¿Qué tareas puede hacer un LLM?
# Debido a que han "leído" tanto texto, son extremadamente versátiles:
# * **Redacción y creatividad:** Escribir correos, ensayos, poemas o guiones.
# * **Resumen:** Leer un documento de 50 páginas y extraer los puntos clave.
# * **Traducción:** Traducir entre decenas de idiomas conservando el contexto.
# * **Programación:** Escribir, corregir y explicar código informático (Python, JavaScript, etc.).
# * **Chatbots:** Mantener conversaciones fluidas y responder dudas de soporte técnico o educativo.
#
# ---
#
# ### 5. Sus principales limitaciones
# A pesar de lo impresionantes que son, los LLM tienen problemas importantes:
# * **"Alucinaciones":** A veces inventan datos, fechas o hechos falsos, pero los presentan con tanta seguridad que parecen reales.
# * **Falta de comprensión real:** No tienen conciencia, sentido común ni entienden el mundo real; solo manipulan patrones estadísticos del lenguaje.
# * **Sesgos:** Si los datos de internet con los que se entrenaron contienen prejuicios raciales, de género o culturales, el modelo puede reproducirlos.
#
# **En resumen:** Un LLM es una herramienta de IA que ha "leído" casi todo el texto disponible en internet y utiliza esa experiencia para predecir y generar lenguaje humano con una precisión asombrosa.
