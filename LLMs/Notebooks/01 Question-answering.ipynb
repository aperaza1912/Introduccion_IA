# %%
# !pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ##Question-answering
# https://huggingface.co/mrm8488/longformer-base-4096-spanish-finetuned-squad

# %%
from transformers import pipeline
qa_pipe = pipeline("question-answering", model='mrm8488/longformer-base-4096-spanish-finetuned-squad')
# Out:
# Device set to use mps:0

# %%
context = '''
Hace aproximadamente un año, Hugging Face, una startup de procesamiento de lenguaje natural con sede en Brooklyn, Nueva York, lanzó BigScience, un proyecto internacional con más de 900 investigadores que está diseñado para comprender mejor y mejorar la calidad de los grandes modelos de lenguaje natural. Los modelos de lenguaje grande (LLM), algoritmos que pueden reconocer, predecir y generar lenguaje sobre la base de conjuntos de datos basados ​​en texto, han captado la atención de empresarios y entusiastas de la tecnología por igual. Pero el costoso hardware requerido para desarrollar LLM los ha mantenido en gran medida fuera del alcance de los investigadores sin los recursos de compañías como OpenAI y DeepMind detrás de ellos.

Inspirándose en organizaciones como la Organización Europea para la Investigación Nuclear (también conocida como CERN) y el Gran Colisionador de Hadrones, el objetivo de BigScience es crear LLM y grandes conjuntos de datos de texto que eventualmente serán de código abierto para la IA más amplia. comunidad. Los modelos serán entrenados en la supercomputadora Jean Zay ubicada cerca de París, Francia, que se encuentra entre las máquinas más poderosas del mundo.
'''
question = "¿Cuál es el objetivo de BigScience?"

qa_pipe({'context':context, 'question': question})
# Out:
# {'score': 0.9999698400497437,
#  'start': 224,
#  'end': 305,
#  'answer': 'comprender mejor y mejorar la calidad de los grandes modelos de lenguaje natural.'}

# %%
context = '''
Inteligencia Artificial, Cómputo Científico, Ciencias de Datos, Redes de Computadoras, Sistemas Operativos, Realidad Aumentada, entre otros.

Un egresado de la licenciatura de Ciencias de la Computación tiene un campo laboral que incluye: soporte a la industria 4.0, centros de investigación, centros de cómputo en empresas públicas y privadas, cualquier ámbito en donde se requieran sistemas de procesamiento de información, instituciones educativas, compañías especializadas en desarrollo e implementación de software, administración a redes de datos, y muchas opciones más.

En esta carrera se presentan las bases matemáticas que dan paso a las aplicaciones de la computación. También se da una introducción a la algoritmia y programación. Es cuestión de práctica. Si te gustan las matemáticas y lógica, la programación y los retos ¡te recomendamos Ciencias de la Computación!

Es la utilización de las bases matemáticas y algorítmicas para poder realizar simulaciones en diferentes ámbitos.

Solo se requiere una computadora (portátil de preferencia).

El plan actual tiene una duración desde 9 semestres a 18 semestres.

Es el diagnóstico de problemas sobre el manejo de la información (o de algún equipo) para poder administrar una solución tomando en cuenta la necesidad de información y el software que se tiene que desarrollar.

Formar profesionales para desarrollar y gestionar tecnología computacional; realizar actividades de investigación científica; y diseñar e implementar de forma eficiente software de base y software de aplicación, con un enfoque novedoso y de vanguardia; en donde se toman en cuenta las necesidades de manejo de información de las organizaciones, con apego a la ética profesional y el servicio a la sociedad.

Las ciencias de la computación pueden pensarse como el estudio de los algoritmos. Como área general, las ciencias de la computación tiene toda una serie de ramas específicas: la inteligencia artificial, realidad aumentada, computación gráfica, bioinformática o redes de computadora, cómputo científico, entre otras muchas áreas.

Significa Licenciatura en Ciencias de la Computación.

Es todo aquel software que utilizamos de diferentes formas y en diferentes ámbitos, para diferentes motivos.

Es el software que maneja el usuario.

Es todo el software que hay detrás del software de aplicación; por ejemplo, el sistema operativo, el navegador web, los compiladores, etc.

Ciencias de la Computación se enfoca en las bases de la computación, en el desarrollo de algoritmos, investigación y en el software de base. Se trata de idear soluciones innovadoras a problemas de cómputo que puedan aplicarse a productos o tecnologías de vanguardia. En las otras licenciaturas se enfocan más al desarrollo de productos (Ingeniería de software) o al estudio y desarrollo de componentes electrónicos (hardware) relacionados con la computación (Ingeniería en Computación).
'''
question = "que es ciencias de la computacion"

qa_pipe({'context':context, 'question': question})
# Out:
# {'score': 0.008468566462397575,
#  'start': 1747,
#  'end': 1828,
#  'answer': 'Las ciencias de la computación pueden pensarse como el estudio de los algoritmos.'}
