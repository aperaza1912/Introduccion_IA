# %% [markdown]
# Tutorial original en ultralytics
#
# https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb#scrollTo=bpF9-vS_DAaf
#
#
# App para anotar/etiquetar imágenes de nuestra propia base de datos:
#
# https://app.roboflow.com/login

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 47.5/112.6 GB disk)

# %% [markdown]
# # 1. Predict
#
# YOLOv8 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLOv8 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Found https://ultralytics.com/images/zidane.jpg locally at zidane.jpg
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 11.3ms
# Speed: 47.3ms preprocess, 11.3ms inference, 30.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict-5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ## 1. Detection
#
# YOLOv8 _detection_ models have no suffix and are the default YOLOv8 models, i.e. `yolov8n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg', save=True)  # predict on an image
# Out:
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from IPython.display import Image, display
display(Image(filename='/content/runs/detect/predict-2/bus.jpg', width=600))

# %% [markdown]
# # Sección 2 - Modificado para entrega
# ## Alumno: Alan Peraza

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='mi_foto.jpg'
# Out:
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/mi_foto.jpg: 640x544 1 person, 1 dog, 5 sheeps, 1 bear, 7.6ms
# Speed: 43.6ms preprocess, 7.6ms inference, 17.0ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to /content/runs/detect/predict-7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Load YOLOv8n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('/content/mi_foto.jpg', save=True)  # predict on an image
# Out:
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from IPython.display import Image, display
display(Image(filename='/content/runs/detect/predict-8/mi_foto.jpg', width=600))

# %%
# Reto opcional - Cambiar parámetro conf
# !yolo predict model=yolov8n.pt source='mi_foto.jpg' conf=0.7
# Out:
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/mi_foto.jpg: 640x544 1 person, 1 sheep, 8.2ms
# Speed: 47.4ms preprocess, 8.2ms inference, 23.4ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to /content/runs/detect/predict-9
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image, display
display(Image(filename='/content/runs/detect/predict-9/mi_foto.jpg', width=600))

# %%
# Cambiar solo el modelo de predicción
# !yolo predict model=yolov8s.pt source='mi_foto.jpg'
# Out:
# ...
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8s summary (fused): 72 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /content/mi_foto.jpg: 640x544 1 person, 2 birds, 4 sheeps, 15.9ms
# Speed: 40.0ms preprocess, 15.9ms inference, 17.4ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to /content/runs/detect/predict-10
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Usar un vídeo corto
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='coco128.yaml', epochs=3)  # train the model
model('/content/playa.mp4', save=True)  # predict on a video
# Out:
# Ultralytics 8.4.150 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
